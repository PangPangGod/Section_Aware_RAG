# %%
text1="Jun 2014 Rev. #: Revision Date: Revision - Change Reason Changed Approved 3 6/18/2009 Revise specification. Change Vanadium from 0.075 - 0.100 Jessica Merczak Keith Paarfusser AMERICAN NTN BEARING MFG. CORP. ELGIN PLANT 4/4 BRG. NO. HUB BEARINGS"
text2="BRG. NO. HUB BEARINGS STANDARDIZATION OF PRODUCT QUALITY MACHINE N/A NO. 06-M-5010.005"
text3="Jun 2014 Rev. #: Revision Date: Revision - Change Reason Changed Approved 3 6/18/2009 Revise specification. Change Vanadium from 0.075 - 0.100 Jessica Merczak Keith Paarfusser AMERICAN NTN BEARING MFG. CORP. ELGIN PLANT 4/4 BRG. NO. HUB BEARINGS"

# %%
from difflib import SequenceMatcher

ratio = SequenceMatcher(None, text2, text3).ratio()
print(ratio)
# Out:
# 0.1268882175226586

# %%
import pymupdf4llm

md_text = pymupdf4llm.to_markdown("preprocess_document/output/sample.pdf")

print(md_text)
# Out:
# ## Mercedes-Benz ## DBL 4027
#
# ![sample.pdf-0-0.png](sample.pdf-0-0.png)
#
# ![sample.pdf-0-1.png](sample.pdf-0-1.png)
#
# ![sample.pdf-0-2.png](sample.pdf-0-2.png)
#
# ![sample.pdf-0-3.png](sample.pdf-0-3.png)
#
# ![sample.pdf-0-4.png](sample.pdf-0-4.png)
#
# ![sample.pdf-0-5.png](sample.pdf-0-5.png)
#
# ![sample.pdf-0-6.png](sample.pdf-0-6.png)
#
# # Supply Specification
#  Case Hardening Steels
#
# **Foreword**
#
# ![sample.pdf-0-10.png](sample.pdf-0-10.png)
#
# ![sample.pdf-0-11.png](sample.pdf-0-11.png)
#
# ![sample.pdf-0-12.png](sample.pdf-0-12.png)
#
# ![sample.pdf-0-13.png](sample.pdf-0-13.png)
#
# **Preamble:**
#
# ![sample.pdf-0-14.png](sample.pdf-0-14.png)
#
# ![sample.pdf-0-15.png](sample.pdf-0-15.png)
#
# ![sample.pdf-0-16.png](sample.pdf-0-16.png)
#
# ![sample.pdf-0-17.png](sample.pdf-0-17.png)
#
# ![sample.pdf-0-18.png](sample.pdf-0-18.png)
#
# ![sample.pdf-0-19.png](sample.pdf-0-19.png)
#
# ![sample.pdf-0-20.png](sample.pdf-0-20.png)
#
# ...
